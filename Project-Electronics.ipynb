# %% [markdown]
# # Load the dataset into pandas and provide a summary of columns in the loaded dataset without any modification.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv(r"C:\Users\acer\Desktop\electronics.csv")
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %% [markdown]
# # Prepare the data

# %% [markdown]
# # Step 1 check for null values, drop it and cross check

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# # Step 2 check for duplicate values and drop it

# %%
df2=df1.drop_duplicates()
df2
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# # Step 3 rectify column name

# %%
df2.columns=['Order_ID','Product','Quantity_Ordered','Price_Each','Order_Date','Purchase_address']
df2.head
# Out:
# <bound method NDFrame.head of       Order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order_Date                        Purchase_address
# ...

# %% [markdown]
# # Step 4 Extract date from order date

# %%
df2['Date']=df2['Order_Date'].str[:8]
df2
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\1102692406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date']=df2['Order_Date'].str[:8]
#       Order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18268 entries, 0 to 18382
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          18268 non-null  object
#  1   Product           18268 non-null  object
#  2   Quantity_Ordered  18268 non-null  object
#  3   Price_Each        18268 non-null  object
#  4   Order_Date        18268 non-null  object
#  5   Purchase_address  18268 non-null  object
#  6   Date              18268 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# # Step 5 extract month from order date

# %%
df2['Month']=df2['Date'].str[:2]
df2
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\2072781436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Month']=df2['Date'].str[:2]
#       Order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# ...

# %% [markdown]
# # Step 6 extract house_no ,city and pin code from address

# %%
df2[['House_No','City','Pin_Code']]=df2.Purchase_address.str.split(",",expand=True)
df2
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\3750398240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['House_No','City','Pin_Code']]=df2.Purchase_address.str.split(",",expand=True)
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\3750398240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['House_No','City','Pin_Code']]=df2.Purchase_address.str.split(",",expand=True)
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\3750398240.py:1: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Step 7 Check for month column for bad data entry and remove it

# %%
df2.Month.value_counts()
# Out:
# Month
# 04    18239
# 05       28
# Or        1
# Name: count, dtype: int64

# %%
df2=df2[df2['Month'].str[:2] !='Or']
df2.head()
# Out:
#   Order_ID                     Product Quantity_Ordered Price_Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order_Date                      Purchase_address      Date Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001  04/19/19    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215  04/07/19    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001  04/30/19    04
#
#           House_No          City   Pin_Code
# 0       917 1st St        Dallas   TX 75001
# ...

# %%
df2.shape
# Out:
# (18267, 11)

# %% [markdown]
# # Step 8 correct data types

# %%
df2['Month']=df2['Month'].astype('int32')
df2['Order_Date']=pd.to_datetime(df2['Order_Date'])
df2['Date']=pd.to_datetime(df2['Date'])
df2.info()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\3898704933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Month']=df2['Month'].astype('int32')
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\3898704933.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2['Order_Date']=pd.to_datetime(df2['Order_Date'])
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          18267 non-null  object
# ...

# %% [markdown]
# # Step 9 make Sales Column (hint Quantity_ordered * Price_each)

# %%
df2['Quantity_Ordered']=df2['Quantity_Ordered'].astype('int32')
df2['Price_Each']=df2['Price_Each'].astype('float64')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          18267 non-null  object
#  1   Product           18267 non-null  object
#  2   Quantity_Ordered  18267 non-null  int32
#  3   Price_Each        18267 non-null  float64
#  4   Order_Date        18267 non-null  datetime64[ns]
#  5   Purchase_address  18267 non-null  object
#  6   Date              18267 non-null  datetime64[ns]
#  7   Month             18267 non-null  int32
#  8   House_No          18267 non-null  object
#  9   City              18267 non-null  object
#  10  Pin_Code          18267 non-null  object
# dtypes: datetime64[ns](2), float64(1), int32(2), object(6)
# memory usage: 1.5+ MB
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\1164615490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2['Sales']=df2['Quantity_Ordered']*df2['Price_Each']
df2
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\1867050055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Sales']=df2['Quantity_Ordered']*df2['Price_Each']
#       Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# ...

# %% [markdown]
# #  Sales Value by Each Month

# %% [markdown]
# Monthly_sales= df2.groupby('Month').Sales.sum()
# Monthly_sales

# %% [markdown]
# # City had the highest sales overall

# %%
city_sales=df2.City.value_counts()
city_sales
# Out:
# City
#  San Francisco    4434
#  Los Angeles      3021
#  New York City    2429
#  Boston           1915
#  Atlanta          1470
#  Seattle          1440
#  Dallas           1348
#  Portland         1237
#  Austin            973
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.countplot(x=df2['city'])
plt.xlabel("City name")
plt.ylabel("Number of sells")
plt.title("City vs sales")
# Out:
# Text(0.5, 1.0, 'City vs sales')

# %% [markdown]
# # Distribution of sales over different times of the day (Morning, Afternoon, Evening, Night)

# %%
df2['Hour']=df2.Order_Date.dt.hour
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6724\348913851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Hour']=df2.Order_Date.dt.hour

# %%
df2.groupby('Hour').count()
# Out:
#       Order_ID  Product  Quantity_Ordered  Price_Each  Order_Date  \
# Hour
# 0          377      377               377         377         377
# 1          243      243               243         243         243
# 2          132      132               132         132         132
# 3           85       85                85          85          85
# 4           84       84                84          84          84
# 5          143      143               143         143         143
# 6          254      254               254         254         254
# 7          384      384               384         384         384
# 8          642      642               642         642         642
# 9          869      869               869         869         869
# 10        1133     1133              1133        1133        1133
# 11        1200     1200              1200        1200        1200
# 12        1199     1199              1199        1199        1199
# ...

# %%
hours=[hour for hour , df2 in df2.groupby('Hour')]
plt.plot(hours, df2.groupby('Hour').count())
plt.grid()
plt.xticks(hours)
plt.xlabel('Hours in 24 hr format')
plt.ylabel('Orders')
plt.show()

# %% [markdown]
# # Highest Product Sold by Amount and Numbers

# %%
highest_orders=df2.Product.value_counts()
highest_sales=df2.groupby('Product').Sales.sum().sort_values(ascending=False)
fig,axes=plt.subplots(1,2,figsize=(20,7))
sns.barplot(ax=axes[0],x=highest_orders.index,y=highest_orders.values)
axes[0].set_xlabel('Products')
axes[0].set_ylabel('No of Orders')
axes[0].tick_params(axis='x',rotation=90)
sns.barplot(ax=axes[1],x=highest_sales.index,y=highest_sales.values)
axes[1].set_xlabel('Products')
axes[1].set_ylabel('Sales Amount')
axes[1].tick_params(axis='x',rotation=90)
